# %%
import pandas as pd
import numpy as np

url= "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv"
df=pd.read_csv(url)

# %%
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df["Response"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
grouped = df.groupby("Response")
grouped

# %%
for resp, group in grouped:
    print(f"Group who responde: {resp}")
    display(group)
# Out:
# Group who responde: No
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 4               4  QA50777      Oregon              9025.067525       No
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
# ...

# %%
grouped.size()
# Out:
# Response
# No     8813
# Yes    1466
# dtype: int64

# %%
claim = df.groupby("Response")["Total Claim Amount"].max()
claim
# Out:
# Response
# No     2893.239678
# Yes    1358.400000
# Name: Total Claim Amount, dtype: float64

# %%
grouped.get_group('Yes')
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 3               3  XL78013      Oregon             22332.439460      Yes
# 8               8  FM55990  California              5989.773931      Yes
# 15             15  CW49887  California              4626.801093      Yes
# 19             19  NJ54277  California              3746.751625      Yes
# 27             27  MQ68407      Oregon              4376.363592      Yes
# ...           ...      ...         ...                      ...      ...
# 10844       10844  FM31768     Arizona              5979.724161      Yes
# 10852       10852  KZ80424  Washington              8382.478392      Yes
# 10872       10872  XT67997  California              5979.724161      Yes
# 10887       10887  BY78730      Oregon              8879.790017      Yes
# 10897       10897  MM70762     Arizona              9075.768214      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
condition2=grouped.get_group('Yes')[grouped.get_group('Yes')['Total Claim Amount'] < 1000]
condition2
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 3               3  XL78013      Oregon             22332.439460      Yes
# 8               8  FM55990  California              5989.773931      Yes
# 15             15  CW49887  California              4626.801093      Yes
# 19             19  NJ54277  California              3746.751625      Yes
# 27             27  MQ68407      Oregon              4376.363592      Yes
# ...           ...      ...         ...                      ...      ...
# 10844       10844  FM31768     Arizona              5979.724161      Yes
# 10852       10852  KZ80424  Washington              8382.478392      Yes
# 10872       10872  XT67997  California              5979.724161      Yes
# 10887       10887  BY78730      Oregon              8879.790017      Yes
# 10897       10897  MM70762     Arizona              9075.768214      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
df.groupby(['Gender', 'Policy Type'])['Monthly Premium Auto'].agg (["mean"])
# Out:
#                             mean
# Gender Policy Type
# F      Corporate Auto  91.384615
#        Personal Auto   93.153179
#        Special Auto    93.563025
# M      Corporate Auto  94.764249
#        Personal Auto   93.301056
#        Special Auto    93.197044

# %%
df.groupby('State')

# %%
total = df.groupby("State")["Customer"].count()
total
# Out:
# State
# Arizona       1937
# California    3552
# Nevada         993
# Oregon        2909
# Washington     888
# Name: Customer, dtype: int64

# %%
df.groupby(['Gender', 'Education'])['Customer Lifetime Value'].agg (["mean","max","min","median"])
# Out:
#                                     mean          max          min  \
# Gender Education
# F      Bachelor              7874.269478  73225.95652  1904.000852
#        College               7748.823325  61850.18803  1898.683686
#        Doctor                7328.508916  44856.11397  2395.570000
#        High School or Below  8675.220201  55277.44589  2144.921535
#        Master                8157.053154  51016.06704  2417.777032
# M      Bachelor              7703.601675  67907.27050  1898.007675
#        College               8052.459288  61134.68307  1918.119700
#        Doctor                7415.333638  32677.34284  2267.604038
#        High School or Below  8149.687783  83325.38119  1940.981221
#        Master                8168.832659  50568.25912  2272.307310
#
#                                   median
# Gender Education
# F      Bachelor              5640.505303
#        College               5623.611187
#        Doctor                5332.462694
# ...
